# %%
'''
Visualisation d’un nuage de points et exploration des variables
'''

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ouverture du fichier 
dfExplo = pd.read_csv("data/house_pricing.csv",",",encoding='utf-8', low_memory=False)

dfExplo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
# En créant un nuage de points, regardez comment se comporte la colonne LotArea par rapport au SalesPrices 
g = sns.scatterplot(x="LotArea", y="SalePrice", data=dfExplo)

# %%
# Affinez votre visualisation en ne gardant uniquement les maisons qui ont un LotArea inférieur à 20 000 pieds carrés et un prix inférieur à 500 000$
dfMini = dfExplo[dfExplo['LotArea'] < 20000]
dfMini = dfMini[dfMini['SalePrice'] < 500000]
g = sns.scatterplot(x="LotArea", y="SalePrice", data=dfMini)

# %%
# En créant un nuage de points, regardez la relation entre le LotFrontage et le LotArea
g = sns.scatterplot(x="LotArea", y="LotFrontage", data=dfExplo)

# %%
# De la même manière, affinez votre visualisation en ne gardant uniquement les maisons qui ont un LotFrontage inférieur à 200 pieds carrés et un LotArea inférieur à 100000 pieds carré
dfMini = dfExplo[dfExplo['LotArea'] < 100000]
dfMini = dfMini[dfMini['LotFrontage'] < 200]
g = sns.scatterplot(x="LotArea", y="LotFrontage", data=dfMini)

# %%
'''
Visualisation de relations continues 
'''
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dfCont = pd.read_csv("data/sales_predictions.csv",",",encoding='utf-8', low_memory=False)
dfCont
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
# En utilisant relplot(), construisez un graphique qui va vous permettre de voir l’évolution des prix par rapport au temps. Que pouvez vous voir ? 
g = sns.relplot(x="date", y="item_price",kind="line", data=dfCont)
# On peux voir grand chose

# %%
# Corrigeons le problème de visualisation, en utilisant la fonction .sample() de Pandas, prenez un échantillons de 50 éléments dans votre dataset

dfMinim = dfCont.sample(n=10, random_state=1)

g = sns.relplot(x="date", y="item_price",kind="line", data=dfMinim)

# %%
# Retentez de faire votre visualisation, créez une figure de taille (20,6). Que voyez vous ? 
# En utilisant la fonction pd.to_datetime(), convertissez votre colonne date en datetime 
import seaborn as sns
pd.to_datetime(df['date'])
x = sns.relplot(x="date", y="item_price",kind="line", data=dfMinim,sizes=(20,6))

# %%
'''
Visualisation de variables catégoriques
'''
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dfCat = pd.read_csv("data/IBM_HR_ATTRITION.csv",",",encoding='utf-8', low_memory=False)
dfCat
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
dfCat.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
dfCat['JobSatisfaction'].describe()
# Out:
# count    1470.000000
# mean        2.728571
# std         1.102846
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: JobSatisfaction, dtype: float64

# %%
# En utilisant catplot(), construisez un graphique qui vous permette de voir la distribution des personnes qui ont quitté l’entreprise par rapport à leur JobSatisfaction
dfCatViz = dfCat[dfCat['Attrition'] == 'Yes']
sns.catplot(x="Attrition", y="JobSatisfaction", data=dfCatViz)

# %%
# Changez de graphique et utilisez plutôt un boxplot, que pouvez vous conclure ?
ax = sns.boxplot(x="Attrition", y="JobSatisfaction", data=dfCatViz)
# Qu'il n'y a pas de relation entre le JobSatisfaction des personnes dans leur job et le fait qu'il parte.

# 4) Le Job Satisfaction présent dans données aberrantes

# %%
# Isolez les observations présentant des valeurs aberrantes pour la variable JobSatisfaction en fonction de la variable indiquant 
# si ils ont quitté l’entreprise ou nom
df1 = dfCat[(dfCat['Attrition'] == 'Yes') & (dfCat['JobSatisfaction'] > 2)]
df2 = dfCat[(dfCat['Attrition'] == 'No') & (dfCat['JobSatisfaction'] < 2)]
dfConcat = pd.concat([df1,df2])
dfConcat
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 0      41       Yes  Travel_Rarely       1102                   Sales
# 2      37       Yes  Travel_Rarely       1373  Research & Development
# 14     28       Yes  Travel_Rarely        103  Research & Development
# 33     39       Yes  Travel_Rarely        895                   Sales
# 34     24       Yes  Travel_Rarely        813  Research & Development
# ...   ...       ...            ...        ...                     ...
# 1436   21        No  Travel_Rarely        501                   Sales
# 1449   32        No  Travel_Rarely        529  Research & Development
# 1460   29        No  Travel_Rarely        468  Research & Development
# 1463   31        No     Non-Travel        325  Research & Development
# 1466   39        No  Travel_Rarely        613  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
# Utilisez la méthode .describe de pandas pour obtenir un tableau récapitulatif des statistiques descriptives du dataset.
dfCat.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
'''
Comparez les individus présentant des valeurs aberrantes pour la variable JobSatisfaction avec 
les statistiques descriptives du dataset, remarquez vous des différences notoires ?
'''
# Il n'y a pas de diff notable

# %%
dfCat['Attrition'] = dfCat['Attrition'].replace('No',0).replace('Yes',1)

# %%
dfCat
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
plt.figure(figsize=(16,7))
sns.catplot(x="EducationField",  y="Attrition",data=dfCat, kind='bar')

# %%
'''
Visualisation d’une distribution
'''
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dfDistr = pd.read_csv("data/IBM_HR_ATTRITION.csv",",",encoding='utf-8', low_memory=False)

# %%
sns.distplot(dfDistr['MonthlyIncome'])

# %%
dfDistr = dfDistr[dfDistr['MonthlyIncome'] <= 5000]

# %%
sns.distplot(dfDistr['MonthlyIncome'])

# %%
'''
Visualisation d’une relation linéaire
'''
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dfRl = pd.read_csv("data/IBM_HR_ATTRITION.csv",",",encoding='utf-8', low_memory=False)
dfRl['Attrition'] = dfRl['Attrition'].replace('No',0).replace('Yes',1)
sns.lmplot(x="DistanceFromHome", y="Attrition", data=dfRl)

# %%
dfRl.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
sns.lmplot(x="YearsWithCurrManager", y="Attrition", data=dfRl)

# %%
'''
Visualisation d’une heatmap
'''
# Importez les librairies habituelles
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dfHmp = pd.read_csv("data/house_pricing.csv",",",encoding='utf-8', low_memory=False)

# Découpez votre dataset pour ne garder que les 15 dernieres colonnes
dfHmp = dfHmp.drop(dfHmp.columns[:-15],axis=1)
dfHmp.columns
# Out:
# Index(['WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'PoolQC', 'Fence', 'MiscFeature', 'MiscVal',
#        'MoSold', 'YrSold', 'SaleType', 'SaleCondition', 'SalePrice'],
#       dtype='object')

# %%
# Créez une matrice de corrélation avec toutes les variables du Dataset
corrMatrix = dfHmp.corr()
corrMatrix
# Out:
#                WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# WoodDeckSF       1.000000     0.058661      -0.125989  -0.032771    -0.074181
# OpenPorchSF      0.058661     1.000000      -0.093079  -0.005842     0.074304
# EnclosedPorch   -0.125989    -0.093079       1.000000  -0.037305    -0.082864
# 3SsnPorch       -0.032771    -0.005842      -0.037305   1.000000    -0.031436
# ScreenPorch     -0.074181     0.074304      -0.082864  -0.031436     1.000000
# PoolArea         0.073378     0.060762       0.054203  -0.007992     0.051307
# MiscVal         -0.009551    -0.018584       0.018361   0.000354     0.031946
# MoSold           0.021011     0.071255      -0.028887   0.029474     0.023217
# YrSold           0.022270    -0.057619      -0.009916   0.018645     0.010694
# SalePrice        0.324413     0.315856      -0.128578   0.044584     0.111447
#
#                PoolArea   MiscVal    MoSold    YrSold  SalePrice
# ...

# %%
sns.heatmap(corrMatrix)

# %%
# Quel est le top 3 des features qu’on devrait garder pour prédire notre prix ?
# SalePrice, OpenPorchSF & WoodDeckSF

# %%
'''
Formaliser des KPI
'''

# Se renseigner sur ce qu’est un KPI: Key Performance Indicator : Indicateur servant à vérifier la performance d'un système
# Qu'il soit économique, opérationnelle, managérial ou encore informatique

# Importez les bonnes librairies et le dataset resto.csv 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

dfResto = pd.read_csv("data/resto.csv",",",encoding='utf-8', low_memory=False)

# Regardez les 10 premières lignes du dataset
dfResto.head(10)
# Out:
#    Unnamed: 0  order_id  quantity                              item_name  \
# 0           0         1         1           Chips and Fresh Tomato Salsa
# 1           1         1         1                                   Izze
# 2           2         1         1                       Nantucket Nectar
# 3           3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4           4         2         2                           Chicken Bowl
# 5           5         3         1                           Chicken Bowl
# 6           6         3         1                          Side of Chips
# 7           7         4         1                          Steak Burrito
# 8           8         4         1                       Steak Soft Tacos
# 9           9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# ...

# %%
# Quelle est la taille de notre dataset ?
len(dfResto)
# Out:
# 4622

# %%
# Affichez toutes les colonnes de notre dataset
dfResto.columns
# Out:
# Index(['Unnamed: 0', 'order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# Quel est l’item le plus commandé
dfResto['item_name'].value_counts()
# Réponse : Chicken Bowl
# Out:
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chips and Guacamole                      479
# Steak Burrito                            368
# Canned Soft Drink                        301
# Chips                                    211
# Steak Bowl                               211
# Bottled Water                            162
# Chicken Soft Tacos                       115
# Chicken Salad Bowl                       110
# Chips and Fresh Tomato Salsa             110
# Canned Soda                              104
# Side of Chips                            101
# Veggie Burrito                            95
# Barbacoa Burrito                          91
# Veggie Bowl                               85
# Carnitas Bowl                             68
# Barbacoa Bowl                             66
# Carnitas Burrito                          59
# Steak Soft Tacos                          55
# 6 Pack Soft Drink                         54
# ...

# %%
# Combien d’items ont été commandés au total chez Chipotle
sum(dfResto['quantity'])
# Out:
# 4972

# %%
# Combien de chiffre d’affaire à realisé Chipotle ?
dfResto['item_price_int'] = dfResto['item_price'].str.slice(start=1)
dfResto['item_price_int'] = pd.to_numeric(dfResto['item_price_int'])
dfResto['quantity'] = pd.to_numeric(dfResto['quantity'])
dfResto['CA'] = dfResto['quantity'] * dfResto['item_price_int']
sum(dfResto['CA'])
# Out:
# 39237.020000000055

# %%
# Quel est le revenu moyen par commande ?
dfResto['CA'].describe()
#  8.489186 moyen
# Out:
# count    4622.000000
# mean        8.489186
# std        12.632060
# min         1.090000
# 25%         3.990000
# 50%         8.750000
# 75%        10.980000
# max       663.750000
# Name: CA, dtype: float64
